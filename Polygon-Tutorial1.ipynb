# %%
### For colab, run the following codes
# from google.colab import drive
# drive.mount('/content/gdrive')

### cd to your directory
# %cd /content/gdrive/MyDrive/Your_Dir

### cd to polygon-yolov5
# %cd polygon-yolov5

### install requirements
# !pip install -r requirements.txt

### install cuda extensions for polygon box iou computation
# %cd utils/iou_cuda
# !python setup.py install

### cd back
# %cd ..
# %cd ..

# %% [markdown]
# # 1. Inference
#
# `polygon_detect.py` runs polygon-enabled YOLOv5 inference on a variety of sources, and saving results to `runs/detect`.

# %%
from IPython.display import Image

# !python polygon_detect.py --weights polygon_best.pt --img 640 --conf 0.75 \
    --source data/images/armor --iou-thres 0.4
Image(filename='runs/detect/exp/1070.png', width=1024)
# Out:
# Notice: polygon_detect.py is designed for polygon cases
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.75, device='', exist_ok=False, half=False, hide_conf=False, hide_labels=False, imgsz=640, iou_thres=0.4, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='data/images/armor', update=False, view_img=False, weights=['polygon_best.pt'])
# YOLOv5 🚀 v1.0-24-gd5926bb torch 1.9.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7064698 parameters, 0 gradients, 16.4 GFLOPs
# Used              	Free              	Total
# 2.002 GB    8.45%    	21.694 GB    91.55%   	23.70
# image 1/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10001.jpg: 480x640 1 armor, Done. (0.011s)
# image 2/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10012.jpg: 480x640 1 armor, Done. (0.007s)
# image 3/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10023.jpg: 480x640 Done. (0.005s)
# image 4/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10034.jpg: 480x640 1 armor, Done. (0.007s)
# image 5/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10046.jpg: 480x640 1 armor, Done. (0.007s)
# image 6/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10057.jpg: 480x640 1 armor, Done. (0.007s)
# image 7/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10068.jpg: 480x640 1 armor, Done. (0.007s)
# image 8/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10079.jpg: 480x640 2 armors, Done. (0.012s)
# image 9/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10091.jpg: 480x640 1 armor, Done. (0.007s)
# image 10/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10102.jpg: 480x640 2 armors, Done. (0.008s)
# image 11/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10113.jpg: 480x640 1 armor, Done. (0.007s)
# image 12/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10124.jpg: 480x640 1 armor, Done. (0.008s)
# image 13/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10136.jpg: 480x640 1 armor, Done. (0.008s)
# image 14/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10147.jpg: 480x640 1 armor, Done. (0.007s)
# image 15/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10158.jpg: 480x640 1 armor, Done. (0.007s)
# image 16/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10169.jpg: 480x640 1 armor, Done. (0.007s)
# image 17/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10181.jpg: 480x640 1 armor, Done. (0.007s)
# image 18/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10192.jpg: 480x640 1 armor, Done. (0.007s)
# image 19/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10203.jpg: 480x640 1 armor, Done. (0.007s)
# image 20/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10214.jpg: 480x640 1 armor, Done. (0.007s)
# image 21/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10226.jpg: 480x640 1 armor, Done. (0.007s)
# image 22/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10237.jpg: 480x640 1 armor, Done. (0.007s)
# image 23/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10248.jpg: 480x640 1 armor, Done. (0.007s)
# image 24/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10259.jpg: 480x640 1 armor, Done. (0.007s)
# image 25/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10271.jpg: 480x640 1 armor, Done. (0.007s)
# image 26/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10282.jpg: 480x640 1 armor, Done. (0.007s)
# image 27/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10293.jpg: 480x640 1 armor, Done. (0.007s)
# image 28/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10304.jpg: 480x640 1 armor, Done. (0.007s)
# image 29/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10316.jpg: 480x640 1 armor, Done. (0.007s)
# image 30/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10327.jpg: 480x640 1 armor, Done. (0.007s)
# image 31/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10338.jpg: 480x640 1 armor, Done. (0.007s)
# image 32/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10349.jpg: 480x640 1 armor, Done. (0.008s)
# image 33/33 /home/zq/PolygonObjectDetection/polygon-yolov5/data/images/armor/x1red10361.jpg: 480x640 1 armor, Done. (0.007s)
# Results saved to runs/detect/exp
# Done. (0.554s)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_206321/1685742645.py in <module>
#       2
#       3 get_ipython().system('python polygon_detect.py --weights polygon_best.pt --img 640 --conf 0.75      --source data/images/armor --iou-thres 0.4')
# ----> 4 Image(filename='runs/detect/exp/1070.png', width=1024)
#
# ~/.conda/envs/yolo/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# ~/.conda/envs/yolo/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ~/.conda/envs/yolo/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# ~/.conda/envs/yolo/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/detect/exp/1070.png'

# %% [markdown]
# # 2. Test
# Test the polygon model's accuracy on a subset of [UCAS-AOD] dataset (https://github.com/XinzeLee/PolygonObjectDetection/tree/main/UCAS50). To show results by class use the `--verbose` flag.

# %%
# Run Polygon_Yolov5s on a subset of UCAS-AOD
# !python polygon_test.py --weights polygon-yolov5s-ucas.pt --data polygon_ucas.yaml --img 1024 --iou 0.65 --task val
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/polygon_ucas.yaml', device='', exist_ok=False, half=False, imgsz=1024, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['polygon-yolov5s-ucas.pt'])
# YOLOv5 🚀 0d55d0b torch 1.9.0+cu102 CUDA:0 (NVIDIA Tesla K80, 11441.1875MB)
#
# Fusing layers...
# /home/xinzeli831/miniconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 224 layers, 7067395 parameters, 0 gradients, 16.4 GFLOPs
# val: Scanning '../UCAS50/val' images and labels...:   0%| | 0/9 [00:00<?, ?it/s]val: WARNING: Ignoring corrupted image and/or label ../UCAS50/images/val/964.png: non-normalized or out of bounds coordinate labels
# val: Scanning '../UCAS50/val' images and labels...9 found, 0 missing, 0 empty, 1
# val: New cache created: ../UCAS50/val.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all          8         69      0.955      0.988      0.968       0.63
#                plane          8         27          1          1      0.997      0.769
#                  car          8         42      0.911      0.976       0.94      0.491
# Speed: 0.8ms pre-process, 46.4ms inference, 59.7ms NMS per image at shape (32, 3, 1024, 1024)
# Results saved to runs/test/exp

# %% [markdown]
# # 3. Train

# %% [markdown]
# Train a polygon-YOLOv5s model on [UCAS-AOD train](https://github.com/XinzeLee/PolygonObjectDetection/tree/main/UCAS50) with `--data polygon_ucas.yaml`, starting from pretrained `--weights polygon-yolov5s-ucas.pt`, or from randomly initialized `--weights '' --cfg polygon_yolov5s_ucas`.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %% [markdown]
# ## 3.1 Autoanchor
# * Run utils.polygon_kmean_anchors to generate **predefined anchors** for your specific datasets with specified image size.
# * Notice: For polygon anchor boxes, **minimum outter bounding box** of polygon is used in the kmeans anchor selection.

# %%
from utils.autoanchor import polygon_kmean_anchors

nl = 3 # number of anchor layers
na = 3 # number of anchors
img_size = 640 # image size for training and testing

datacfg = "data/polygon_armor.yaml"
anchors = polygon_kmean_anchors(datacfg, n=nl*na, gen=3000, img_size=img_size)
print(anchors.reshape(nl, na*2).astype(int))
print('\nPlease Copy the anchors to your model configuration polygon_yolov5*.yaml')
# Out:
# Scanning '../armor293/train.cache' images and labels... 293 found, 0 missing, 0 empty, 51 corrupted: 100%|██████████| 293/293 [00:00<?, ?it/s]
# autoanchor: Running kmeans for 9 anchors on 242 points...
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.48 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.519/0.931-mean/best, past_thr=0.583-mean: 29,12,  42,17,  47,20,  71,31,  85,41,  98,42,  101,79,  167,72,  181,80
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9321:  12%|█▏        | 355/3000 [00:00<00:00, 3542.33it/s]
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.48 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.518/0.931-mean/best, past_thr=0.583-mean: 29,12,  42,17,  47,20,  71,31,  85,41,  98,42,  101,79,  167,72,  181,80
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.48 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.518/0.931-mean/best, past_thr=0.583-mean: 29,12,  42,17,  47,20,  71,31,  85,41,  97,42,  101,79,  168,72,  182,80
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.46 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.518/0.931-mean/best, past_thr=0.584-mean: 29,12,  43,17,  47,20,  71,31,  85,42,  99,41,  103,79,  166,72,  181,80
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.46 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.518/0.931-mean/best, past_thr=0.584-mean: 29,12,  43,17,  47,20,  71,31,  85,42,  99,41,  103,79,  166,72,  181,80
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.518/0.931-mean/best, past_thr=0.584-mean: 29,12,  43,17,  47,20,  71,31,  86,42,  99,41,  102,80,  167,72,  181,80
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.518/0.931-mean/best, past_thr=0.585-mean: 29,12,  43,17,  47,20,  71,31,  86,42,  99,41,  102,80,  167,72,  181,80
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.518/0.931-mean/best, past_thr=0.584-mean: 28,12,  43,17,  47,20,  71,31,  86,42,  98,41,  102,81,  167,73,  182,80
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.46 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  86,42,  98,41,  102,81,  169,73,  180,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.46 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  86,42,  98,41,  102,81,  170,73,  180,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.46 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  86,42,  98,41,  102,81,  170,73,  181,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.46 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  86,42,  98,41,  102,81,  170,73,  181,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.46 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  86,42,  98,41,  102,81,  170,73,  181,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.584-mean: 28,12,  43,17,  47,20,  70,31,  85,42,  97,41,  102,81,  170,73,  179,82
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.584-mean: 28,12,  43,17,  47,20,  70,31,  85,42,  97,41,  102,81,  170,73,  179,82
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.584-mean: 28,12,  43,17,  47,20,  70,31,  85,42,  97,41,  102,81,  170,73,  179,82
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.584-mean: 28,12,  43,17,  47,19,  70,31,  86,42,  96,41,  103,82,  170,72,  182,82
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9321:  27%|██▋       | 822/3000 [00:00<00:00, 4203.32it/s]
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.585-mean: 28,12,  43,17,  47,19,  70,31,  85,42,  96,41,  103,82,  170,72,  183,81
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9324:  56%|█████▌    | 1666/3000 [00:00<00:00, 4170.98it/s]
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  85,42,  96,41,  103,81,  169,72,  183,82
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  85,43,  97,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  46,20,  70,31,  86,43,  98,41,  103,81,  168,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  86,43,  98,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.582-mean: 28,12,  43,17,  47,20,  70,31,  86,43,  98,41,  103,81,  168,73,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.582-mean: 28,12,  43,17,  46,20,  70,31,  86,43,  98,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.582-mean: 28,12,  43,17,  47,20,  70,31,  85,43,  98,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.582-mean: 28,12,  43,17,  47,20,  70,31,  85,43,  98,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.582-mean: 28,12,  43,17,  47,20,  70,31,  85,43,  98,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,20,  70,31,  85,43,  98,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  46,20,  70,31,  86,43,  98,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.932-mean/best, past_thr=0.584-mean: 28,12,  43,17,  46,19,  70,31,  86,43,  97,41,  103,81,  168,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.932-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,19,  70,31,  86,43,  97,41,  103,81,  168,72,  182,81
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9328:  86%|████████▌ | 2577/3000 [00:00<00:00, 4383.22it/s]
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.583-mean: 28,12,  43,17,  47,19,  70,31,  86,43,  97,41,  103,81,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.43 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.583-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  170,72,  183,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.39 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.39 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.517/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  170,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  170,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  170,72,  182,81
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9328: 100%|██████████| 3000/3000 [00:00<00:00, 4340.74it/s]
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# autoanchor: thr=0.25: 1.0000 best possible recall, 7.40 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.516/0.933-mean/best, past_thr=0.585-mean: 28,12,  43,17,  46,20,  70,31,  85,43,  97,41,  103,82,  169,72,  182,81
# [[ 28  11  42  16  46  19]
#  [ 69  31  85  42  96  40]
#  [102  81 169  72 181  80]]
#
# Please Copy the anchors to your model configuration polygon_yolov5*.yaml

# %% [markdown]
# ## 3.2 Polygon Dataset with Augmentations
# The following augmentation effects for polygon are shown. For details, please view ***datasets.py polygon_random_perspective, Polygon_LoadImagesAndLabels, polygon_load_mosaic***
# <br> Notice: for the exemplar training on UCAS-AOD, the mosaic and mixup are not used.
# * image HSV-Hue augmentation
# * image HSV-Saturation augmentation
# * image HSV-Value augmentation
# * image rotation
# * image translation
# * image scale
# * image shear
# * image perspective
# * mage flip up-down
# * image flip left-right
# * image mosaic
# * image mixup

# %%
import matplotlib
import matplotlib.pyplot as plt
import yaml
from utils.datasets import create_dataloader
from utils.plots import polygon_plot_images

# %matplotlib inline
    
path = "../UCAS50/images/train"
hyp_dir = "data/hyp.ucas.yaml"
imgsz = 640
batch_size = 1
stride = 32
pad = 0

with open(hyp_dir) as f:
    hyp = yaml.safe_load(f)  # load hyps
# hyp['mixup'] = 1.0    # Modify hyperparameters
# hyp['mosaic'] = 1.0    # Modify hyperparameters
print(hyp)

dataloader, dataset = create_dataloader(path, imgsz, batch_size, int(stride), True,
                                       hyp=hyp, cache=False, rect=False, rank=-1,
                                       world_size=1, augment=True,
                                       pad=pad, workers=0, polygon=True)


imgs, tgts, *_ = next(iter(dataloader))

plt.figure(figsize=(24, 16), dpi=200)
plt.imshow(polygon_plot_images(imgs, tgts))
plt.axis('off')
# Out:
# {'lr0': 0.01, 'lrf': 0.2, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.1, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 30.0, 'translate': 0.1, 'scale': 0.0, 'shear': 5.0, 'perspective': 0.0005, 'flipud': 0.5, 'fliplr': 0.5, 'mosaic': 0.0, 'mixup': 0.0}
# Scanning '../UCAS50/labels/train' images and labels...40 found, 0 missing, 0 empty, 0 corrupted: 100%|█
# (-0.5, 639.5, 639.5, -0.5)

# %%
# Train polygon-YOLOv5s on UCAS-AOD train (a small subset of original data, contain only 40 images) for 3 epochs
# Link: https://github.com/XinzeLee/PolygonObjectDetection/tree/main/UCAS50
# !python polygon_train.py --weights polygon-yolov5s-ucas.pt --cfg polygon_yolov5s_ucas.yaml \
    --data polygon_ucas.yaml --hyp hyp.ucas.yaml --img-size 1024 \
    --epochs 3 --batch-size 12 --noautoanchor --polygon --cache
# Out:
# YOLOv5 🚀 0d55d0b torch 1.9.0+cu102 CUDA:0 (NVIDIA Tesla K80, 11441.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=12, bbox_interval=-1, bucket='', cache_images=True, cfg='./models/polygon_yolov5s_ucas.yaml', data='./data/polygon_ucas.yaml', device='', entity=None, epochs=3, evolve=False, exist_ok=False, global_rank=-1, hyp='./data/hyp.ucas.yaml', image_weights=False, img_size=[1024, 1024], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=True, nosave=False, notest=False, polygon=True, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=12, upload_dataset=False, weights='polygon-yolov5s-ucas.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.1, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=30.0, translate=0.1, scale=0.0, shear=5.0, perspective=0.0005, flipud=0.5, fliplr=0.5, mosaic=0.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     29667  models.yolo.Polygon_Detect              [2, [[31, 30, 28, 49, 50, 31], [46, 45, 58, 58, 74, 74], [94, 94, 115, 115, 151, 151]], [128, 256, 512]]
# /home/xinzeli831/miniconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 283 layers, 7077027 parameters, 7077027 gradients, 16.4 GFLOPs
#
# Transferred 360/362 items from polygon-yolov5s-ucas.pt
# Scaled weight_decay = 0.00046875
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '../UCAS50/train.cache' images and labels... 40 found, 0 missing
# train: Caching images (0.1GB): 100%|████████████| 40/40 [00:00<00:00, 69.57it/s]
# val: Scanning '../UCAS50/val.cache' images and labels... 9 found, 0 missing, 0 e
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# val: Caching images (0.0GB):  12%|██              | 1/8 [00:00<00:00,  7.21it/s]
# val: Caching images (0.0GB):  62%|██████████      | 5/8 [00:00<00:00,  9.16it/s]
# val: Caching images (0.0GB): 100%|████████████████| 8/8 [00:00<00:00, 18.63it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# val: Scanning '../UCAS50/val.cache' images and labels... 9 found, 0 missing, 0 e
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# val: Scanning '../UCAS50/val.cache' images and labels... 9 found, 0 missing, 0 e
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Plotting labels...
# val: Scanning '../UCAS50/val.cache' images and labels... 9 found, 0 missing, 0 e
# val: Scanning '../UCAS50/val.cache' images and labels... 9 found, 0 missing, 0 e
# Image sizes 1024 train, 1024 test
# Using 4 dataloader workers
# Logging results to runs/train/exp
# Starting training for 3 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#        0/2     4.22G   0.03018    0.0283 2.921e-05   0.05851        19      1024
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all          8         69      0.955      0.988      0.971      0.628
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#        1/2     5.81G   0.05257   0.02727 7.789e-05   0.07992        19      1024
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all          8         69      0.955      0.988      0.974      0.628
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#        2/2     5.81G   0.03351   0.02756 3.457e-05    0.0611        19      1024
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all          8         69      0.955      0.988      0.973      0.627
#                plane          8         27          1          1      0.997      0.765
#                  car          8         42      0.911      0.976      0.948       0.49
# 3 epochs completed in 0.016 hours.
#
# Optimizer stripped from runs/train/exp/weights/polygon_last.pt, 14.5MB
# Optimizer stripped from runs/train/exp/weights/polygon_best.pt, 14.5MB

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and test jpgs to see labels, predictions and augmentation effects. If want to use mosaic effects in **DataLoader**, please modify data/hyp.ucas.yaml or related files

# %%
from IPython.display import Image

Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 labels
# Image(filename='runs/train/exp/train_batch1.jpg', width=800)  # train batch 1 labels
# Image(filename='runs/train/exp/train_batch2.jpg', width=800)  # train batch 2 labels

# %% [markdown]
# Training losses and performance metrics are also logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and a custom `results.txt` logfile which is plotted as `results.png` (below) after training completes.

# %%
from IPython.display import Image, display

from utils.plots import plot_results
# notest=True in training, so val losses are not available in the following figures
plot_results(save_dir='runs/train/exp')  # plot all results*.txt as results.png

# %%
from pathlib import Path
from IPython.display import Image, display

result_dir = Path('runs/train/exp')

files = ['confusion_matrix.png', 'P_curve.png', 'PR_curve.png', 'R_curve.png', 'F1_curve.png']

for file in files:
    display(Image(filename=str(result_dir/file), width=800))
